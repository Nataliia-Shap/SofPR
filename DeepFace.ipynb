# %% [markdown]
# <a href="https://colab.research.google.com/github/Nataliia-Shap/SofPR/blob/main/DeepFace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install deepface #install the Deepface Library
# Out:
# ...
#      |████████████████████████████████| 61 kB 3.6 MB/s
# ...
#      |████████████████████████████████| 2.3 MB 11.0 MB/s
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Created wheel for gdown: filename=gdown-4.2.0-py3-none-any.whl size=14273 sha256=fedd593475d5ef3797d8713ccad9510587353318f38bb32aeffd9c829e6e3962
#   Stored in directory: /root/.cache/pip/wheels/8c/17/ff/58721d1fabdb87c21a0529948cf39e2be9af90ddbe4ad65944
# Successfully built gdown
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 3.6.4
#     Uninstalling gdown-3.6.4:
#       Successfully uninstalled gdown-3.6.4
# ...

# %%
 #calling the dependencies
 from deepface import DeepFace
 import cv2
 import matplotlib.pyplot as plt 
  #importing the images
 img1_path = '/content/drive/My Drive/Colab Notebooks/1.png'
 img2_path = '/content/drive/My Drive/Colab Notebooks/2.png'
 img3_path = '/content/drive/My Drive/Colab Notebooks/3.png'
 #confirming the path of images
 img1 = cv2.imread('/content/drive/My Drive/Colab Notebooks/1.jpg')
 img2 = cv2.imread('/content/drive/My Drive/Colab Notebooks/2.jpg') 
 img3 = cv2.imread('/content/drive/My Drive/Colab Notebooks/3.jpg') 
 img4 = cv2.imread('/content/drive/My Drive/Colab Notebooks/4.jpg') 
plt.imshow(img1[:, :, ::-1 ]) #setting value as -1 to maintain saturation
plt.show()
plt.imshow(img2[:, :, ::-1 ]) 
plt.show()

# %%
 #calling VGGFace
 model_name = "VGG-Face"
 model = DeepFace.build_model(model_name) 
DeepFace.verify(img1,img2)
# Out:
# {'distance': 0.27177587167204864,
#  'max_threshold_to_verify': 0.4,
#  'model': 'VGG-Face',
#  'similarity_metric': 'cosine',
#  'verified': True}

# %%
plt.imshow(img3[:, :, ::-1 ]) #setting value as -1 to maintain saturation
plt.show()
DeepFace.verify(img1,img3)
# Out:
# {'distance': 0.4056221889046796,
#  'max_threshold_to_verify': 0.4,
#  'model': 'VGG-Face',
#  'similarity_metric': 'cosine',
#  'verified': False}

# %%
obj = DeepFace.analyze(img4, actions = ['age', 'gender', 'race', 'emotion'])
print(obj["dominant_race"])
print(obj["age"]," years old ",obj["dominant_race"]," ",obj["dominant_emotion"]," ", obj["gender"])
# Out:
# Action: emotion: 100%|██████████| 4/4 [00:02<00:00,  1.77it/s]
# latino hispanic
# 36  years old  latino hispanic   neutral   Man

# %%
model_name = 'Facenet'
#creating a function named resp to store the result
resp = DeepFace.verify(img1,img4,  model_name = model_name)
resp #generating our result
# Out:
# {'distance': 0.5208055398658429,
#  'max_threshold_to_verify': 0.4,
#  'model': 'Facenet',
#  'similarity_metric': 'cosine',
#  'verified': False}
